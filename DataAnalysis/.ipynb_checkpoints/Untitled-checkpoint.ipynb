# %%
import pandas as pd

# %%
initial_data = pd.read_excel('data/initial_data.xlsx')

# %%
initial_data
# Out:
#      Unnamed: 0                                            ADDRESS  \
# 0             0                      г.Калуга, Литейная ул., 25/15
# 1             1                          г.Калуга, Гагарина ул., 1
# 2             2                       г.Калуга, Кибальчича ул., 25
# 3             3                       г.Калуга, Пестеля ул., 60/49
# 4             4                           г.Калуга, Ленина ул., 81
# ..          ...                                                ...
# 412         412                                     д.Чернятино86А
# 413         413        п.Дубовка, квартал 5/15, Центральный перс.6
# 414         414  г.Донской, мкр.Северо-Задонск, Мичурина ул, 76...
# 415         415                         с.Гремячее, Новики ул., 12
# 416         417                     с.Коллонтай, Московская ул, 23
#
#                 CITY             REGION  Postamat_daily  cashbox_daily  \
# 0             КАЛУГА  Калужская область             NaN            3.3
# ...
